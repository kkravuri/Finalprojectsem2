# %%
import os
import shutil

def collect_images_with_captions(image_folder, caption_file, output_folder, num_images=1000):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Read captions from the text file
    with open(caption_file, 'r') as file:
        captions = file.readlines()

    # Get the list of image files in the input folder
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.jpg', '.png'))]

    # Ensure we don't try to collect more images than available
    num_images = min(num_images, len(image_files))

    # Copy the selected images to the output folder
    for i in range(num_images):
        image_filename = image_files[i]
        print('image filename', image_filename)
        caption = captions[i].strip()
        print('caption', caption)

        # Copy image
        source_path = os.path.join(image_folder, image_filename)
        destination_path = os.path.join(output_folder, image_filename)
        
        shutil.copyfile(source_path, destination_path)

        # Write caption to a single text file in the output folder
        captions_filename = "captions.txt"
        captions_path = os.path.join(output_folder, captions_filename)
        with open(captions_path, 'a') as captions_file:
            captions_file.write(f"{caption}\n")

if __name__ == "__main__":
    # Replace these paths with your actual paths
    image_folder_path = "./flickr/Images"
    caption_file_path = "./flickr/captions.txt"   
    output_folder_path = "./SmallDataset_new"

    # Specify the number of images you want to collect
    num_images_to_collect = 2

    # Call the function
    collect_images_with_captions(image_folder_path, caption_file_path, output_folder_path, num_images_to_collect)
# Out:
# image filename 1000268201_693b08cb0e.jpg
# caption image,caption
# image filename 1001773457_577c3a7d70.jpg
# caption 1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Read the captions from the original captions.txt file
    with open(os.path.join(source_folder, 'captions.txt'), 'r') as captions_file:
        captions = captions_file.readlines()

    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'w') as new_captions_file:
        # Iterate over the first num_images_to_copy images
        for i in range(num_images_to_copy):
            # Construct the source and destination paths for each image
            source_image_path = os.path.join(source_folder, 'Images', f'image{i+1}.jpg')
            dest_image_path = os.path.join(dest_folder, f'image{i+1}.jpg')

            # Copy the image to the new folder
            shutil.copyfile(source_image_path, dest_image_path)

            # Write the corresponding caption to the new captions file
            new_captions_file.write(captions[i])

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12408\2376881831.py in <module>
#      30     num_images_to_copy = 2
#      31
# ---> 32     copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)
#      33
#      34     print(f"{num_images_to_copy} images and captions copied successfully.")
#
# ~\AppData\Local\Temp\ipykernel_12408\2376881831.py in copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)
#      20
#      21             # Copy the image to the new folder
# ---> 22             shutil.copyfile(source_image_path, dest_image_path)
#      23
#      24             # Write the corresponding caption to the new captions file
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc:
#     265             try:
#     266                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flickr\\images\\image1.jpg'

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Read the captions from the original captions.txt file
    with open(os.path.join(source_folder, 'captions.txt'), 'r') as captions_file:
        captions = captions_file.readlines()

    # List all files in the source images folder
    image_files = os.listdir(os.path.join(source_folder, 'Images'))

    # Sort the image files based on their names or any specific criteria
    sorted_image_files = sorted(image_files)  # You might need a custom sorting logic here

    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'w') as new_captions_file:
        # Iterate over the first num_images_to_copy images
        for i in range(num_images_to_copy):
            # Construct the source and destination paths for each image
            source_image_path = os.path.join(source_folder, 'images', sorted_image_files[i])
            dest_image_path = os.path.join(dest_folder, sorted_image_files[i])

            # Copy the image to the new folder
            shutil.copyfile(source_image_path, dest_image_path)

            # Write the corresponding caption to the new captions file
            new_captions_file.write(captions[i])

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# 2 images and captions copied successfully.

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Read the image filenames and captions from the original captions.txt file
    with open(os.path.join(source_folder, 'captions.txt'), 'r') as captions_file:
        lines = captions_file.readlines()

    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'w') as new_captions_file:
        # Iterate over the first num_images_to_copy lines
        for line in lines[:num_images_to_copy]:
            # Split the line into image filename and caption
            image_filename, caption = line.strip().split(',', 1)

            # Construct the source and destination paths for each image
            source_image_path = os.path.join(source_folder, 'Images', image_filename)
            dest_image_path = os.path.join(dest_folder, image_filename)

            # Check if the source image file exists before copying
            if os.path.exists(source_image_path):
                # Copy the image to the new folder
                shutil.copyfile(source_image_path, dest_image_path)

                # Write the corresponding caption to the new captions file
                new_captions_file.write(f"{image_filename},{caption}\n")
            else:
                print(f"Warning: Source image '{source_image_path}' not found!")

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# Warning: Source image 'flickr\Images\image' not found!
# 2 images and captions copied successfully.

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Read the image filenames and captions from the original captions.txt file
    with open(os.path.join(source_folder, 'caption_5.txt'), 'r') as captions_file:
        lines = captions_file.readlines()
        print('line',lines)
        # Image filename to search
        
desired_key = '1000268201_693b08cb0e.jpg'

# Filter lines based on the desired key
filtered_lines = [line.strip() for line in lines if line.startswith(desired_key)]

# Print the filtered lines
for line in filtered_lines:
    print(line)



    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'a') as new_captions_file:
        # Iterate over the first num_images_to_copy lines
        for line in lines[:num_images_to_copy]:
            # Split the line into image filename and caption
            image_filename, caption = line.strip().split(',', 1)
            print('image filename',image_filename)
            print('caption',caption)
            print('image_filename....',)

            # Construct the source and destination paths for each image
            source_image_path = os.path.join(source_folder, 'Images', image_filename)
            dest_image_path = os.path.join(dest_folder, image_filename)

            # Check if the source image file exists before copying
            if os.path.exists(source_image_path):
                # Copy the image to the new folder
                shutil.copyfile(source_image_path, dest_image_path)

                # Write the corresponding caption to the new captions file
                new_captions_file.write(f"{image_filename},{caption}\n")
            else:
                print(f"Warning: Source image '{source_image_path}' not found!")

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# line ['1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .\n', '1000268201_693b08cb0e.jpg,A girl going into a wooden building .\n', '1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .\n', '1000268201_693b08cb0e.jpg,A little girl climbing the stairs to her playhouse .\n', '1000268201_693b08cb0e.jpg,A little girl in a pink dress going into a wooden cabin .\n', '1001773457_577c3a7d70.jpg,A black dog and a spotted dog are fighting\n', '1001773457_577c3a7d70.jpg,A black dog and a tri-colored dog playing with each other on the road .\n', '1001773457_577c3a7d70.jpg,A black dog and a white dog with brown spots are staring at each other in the street .\n', '1001773457_577c3a7d70.jpg,Two dogs of different breeds looking at each other on the road .\n', '1001773457_577c3a7d70.jpg,Two dogs on pavement moving toward each other .\n', '1002674143_1b742ab4b8.jpg,A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl .\n', '1002674143_1b742ab4b8.jpg,A little girl is sitting in front of a large painted rainbow .\n', '1002674143_1b742ab4b8.jpg,A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .\n', '1002674143_1b742ab4b8.jpg,There is a girl with pigtails sitting in front of a rainbow painting .\n', '1002674143_1b742ab4b8.jpg,Young girl with pigtails painting outside in the grass .\n', '1003163366_44323f5815.jpg,A man lays on a bench while his dog sits by him .\n', '1003163366_44323f5815.jpg,A man lays on the bench to which a white dog is also tied .\n', '1003163366_44323f5815.jpg,a man sleeping on a bench outside with a white and black dog sitting next to him .\n', '1003163366_44323f5815.jpg,A shirtless man lies on a park bench with his dog .\n', '1003163366_44323f5815.jpg,man laying on bench holding leash of dog sitting on ground']
# image filename 1000268201_693b08cb0e.jpg
# caption A child in a pink dress is climbing up a set of stairs in an entry way .
# image_filename....
# image filename 1000268201_693b08cb0e.jpg
# caption A girl going into a wooden building .
# image_filename....
# 2 images and captions copied successfully.

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # List all files in the source Images folder
    image_files = os.listdir(os.path.join(source_folder, 'Images'))

    # Sort the image files based on their names or any specific criteria
    sorted_image_files = sorted(image_files)  # You might need a custom sorting logic here

    # Read the captions from the original captions.txt file
    with open(os.path.join(source_folder, 'caption_5.txt'), 'r') as captions_file:
        captions_lines = captions_file.readlines()

    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'w') as new_captions_file:
        # Iterate over the sorted image files
        for image_filename in sorted_image_files[:num_images_to_copy]:
            # Find the corresponding caption for the current image
            matching_caption_line = [line.strip() for line in captions_lines if image_filename in line]
            print('matching_caption_line',matching_caption_line)
            
            if matching_caption_line:
                # Extract the caption from the matching line
                matching_caption = matching_caption_line[0].split(',', 1)[1]
                
                # Construct the source and destination paths for each image
                source_image_path = os.path.join(source_folder, 'Images', image_filename)
                dest_image_path = os.path.join(dest_folder, image_filename)

                # Copy the image to the new folder
                shutil.copyfile(source_image_path, dest_image_path)

                # Write the corresponding caption to the new captions file
                new_captions_file.write(f"{image_filename},{matching_caption}\n")
            else:
                print(f"Warning: Caption not found for image '{image_filename}'!")

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# matching_caption_line ['1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .', '1000268201_693b08cb0e.jpg,A girl going into a wooden building .', '1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .', '1000268201_693b08cb0e.jpg,A little girl climbing the stairs to her playhouse .', '1000268201_693b08cb0e.jpg,A little girl in a pink dress going into a wooden cabin .']
# matching_caption_line ['1001773457_577c3a7d70.jpg,A black dog and a spotted dog are fighting', '1001773457_577c3a7d70.jpg,A black dog and a tri-colored dog playing with each other on the road .', '1001773457_577c3a7d70.jpg,A black dog and a white dog with brown spots are staring at each other in the street .', '1001773457_577c3a7d70.jpg,Two dogs of different breeds looking at each other on the road .', '1001773457_577c3a7d70.jpg,Two dogs on pavement moving toward each other .']
# 2 images and captions copied successfully.

# %%
import os
import shutil

def copy_images_and_captions(source_folder, dest_folder, num_images_to_copy):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # List all files in the source Images folder
    image_files = os.listdir(os.path.join(source_folder, 'Images'))

    # Sort the image files based on their names or any specific criteria
    sorted_image_files = sorted(image_files)  # You might need a custom sorting logic here

    # Read the captions from the original captions.txt file
    with open(os.path.join(source_folder, 'captions.txt'), 'r') as captions_file:
        captions_lines = captions_file.readlines()

    # Open a new captions file for writing
    with open(os.path.join(dest_folder, 'new_captions.txt'), 'w') as new_captions_file:
        # Iterate over the sorted image files
        for image_filename in sorted_image_files[:num_images_to_copy]:
            # Find all matching captions for the current image
            matching_captions = [line.strip().split(',', 1)[1] for line in captions_lines if image_filename in line]
            print('matching_caption_line',matching_captions)

            if matching_captions:
                # Construct the source and destination paths for each image
                source_image_path = os.path.join(source_folder, 'Images', image_filename)
                dest_image_path = os.path.join(dest_folder, image_filename)

                # Copy the image to the new folder
                shutil.copyfile(source_image_path, dest_image_path)

                # Write all matching captions to the new captions file
                for caption in matching_captions:
                    new_captions_file.write(f"{image_filename},{caption}\n")
            else:
                print(f"Warning: Captions not found for image '{image_filename}'!")

if __name__ == "__main__":
    source_folder = 'flickr'
    dest_folder = os.path.join(source_folder, 'new_images_folder')
    num_images_to_copy = 2

    copy_images_and_captions(source_folder, dest_folder, num_images_to_copy)

    print(f"{num_images_to_copy} images and captions copied successfully.")
# Out:
# matching_caption_line ['A child in a pink dress is climbing up a set of stairs in an entry way .', 'A girl going into a wooden building .', 'A little girl climbing into a wooden playhouse .', 'A little girl climbing the stairs to her playhouse .', 'A little girl in a pink dress going into a wooden cabin .']
# matching_caption_line ['A black dog and a spotted dog are fighting', 'A black dog and a tri-colored dog playing with each other on the road .', 'A black dog and a white dog with brown spots are staring at each other in the street .', 'Two dogs of different breeds looking at each other on the road .', 'Two dogs on pavement moving toward each other .']
# 2 images and captions copied successfully.
